# %%
print('Ini adalah konvereter suhu')
restart = ('y')
deg = u'\N{DEGREE SIGN}'

while chances >= 0:
  degree = str(input('Masukkan satuan input suhu \nCelcius (C) \nKelvin (K) \nFarenheit (F)'))
  if degree in ('C'):
    C_degree = str(input('Konversi ke Kelvin (K) atau Farenheit (F)?'))
    if C_degree in ('K'):
      C_degree2 = float(input('Masukkan suhu: '))
      C_degree_K = C_degree2 + 273.15
      print('Hasil konversi: ', C_degree_K,deg)
      restart = input('Lakukan konversi lagi? (y/n)')
      if restart in ('n', 'No', 'NO', 'no', 'N'):
        print('Selesai')
        break
    elif C_degree in ('F'):
      C_degree2 = float(input('Masukkan suhu: '))
      C_degree_F = C_degree2 + 32
      print('Hasil konversi: ', C_degree_F,deg)
      restart = input('Lakukan konversi lagi? (y/n)')
      if restart in ('n', 'No', 'NO', 'no', 'N'):
        print('Selesai')
        break
  elif degree in ('K'):
    K_degree = str(input('Konversi ke Celcius (C) atau Farenheit (F)?'))
    if K_degree in ('C'):
      K_degree2 = float(input('Masukkan suhu: '))
      K_degree_C = K_degree2 - 273.15
      print('Hasil konversi: ', K_degree_C,deg)
      restart = input('Lakukan konversi lagi? (y/n)')
      if restart in ('n', 'No', 'NO', 'no', 'N'):
        print('Selesai')
        break
    elif K_degree in ('F'):
      K_degree2 = float(input('Masukkan suhu: '))
      K_degree_F = K_degree2 - 459.67
      print('Hasil konversi: ', K_degree_F,deg)
      restart = input('Lakukan konversi lagi? (y/n)')
      if restart in ('n', 'No', 'NO', 'no', 'N'):
        print('Selesai')
        break
  elif degree in ('F'):
    F_degree = str(input('Konversi ke Celcius (C) atau Kelvin (K)?'))
    if F_degree in ('C'):
      F_degree2 = float(input('Masukkan suhu: '))
      F_degree_C = F_degree2 - 32
      print('Hasil konversi: ', F_degree_C,deg)
      restart = input('Lakukan konversi lagi? (y/n)')
      if restart in ('n', 'No', 'NO', 'no', 'N'):
        print('Selesai')
        break
    elif F_degree in ('K'):
      F_degree2 = float(input('Masukkan suhu: '))
      F_degree_K = F_degree2 +459.676
      print('Hasil konversi: ', F_degree_K,deg)
      restart = input('Lakukan konversi lagi? (y/n)')
      if restart in ('n', 'No', 'NO', 'no', 'N'):
        print('Selesai')
        break
  elif degree != ('C', 'K', 'F'):
    print('Huruf tidak sesuai')
    break
